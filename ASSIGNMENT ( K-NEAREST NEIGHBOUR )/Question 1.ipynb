# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data=pd.read_csv('D:/DATA SCIENCE/ASSIGNMENT/QUESTION/KNN/glass.csv')

# %%
data
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
data.Type.value_counts().sort_index()
# Out:
# Type
# 1    70
# 2    76
# 3    17
# 5    13
# 6     9
# 7    29
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler

# %%
data
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
x=data.iloc[:,0:9]

# %%
x
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
# [214 rows x 9 columns]

# %%
y=data.iloc[:,9]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 209    7
# 210    7
# 211    7
# 212    7
# 213    7
# Name: Type, Length: 214, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor,KNeighborsClassifier
from sklearn import *

# %%
st_data=StandardScaler()
x=st_data.fit_transform(x)

# %%
x
# Out:
# array([[ 0.87286765,  0.28495326,  1.25463857, ..., -0.14576634,
#         -0.35287683, -0.5864509 ],
#        [-0.24933347,  0.59181718,  0.63616803, ..., -0.79373376,
#         -0.35287683, -0.5864509 ],
#        [-0.72131806,  0.14993314,  0.60142249, ..., -0.82894938,
#         -0.35287683, -0.5864509 ],
#        ...,
#        [ 0.75404635,  1.16872135, -1.86551055, ..., -0.36410319,
#          2.95320036, -0.5864509 ],
#        [-0.61239854,  1.19327046, -1.86551055, ..., -0.33593069,
#          2.81208731, -0.5864509 ],
#        [-0.41436305,  1.00915211, -1.86551055, ..., -0.23732695,
#          3.01367739, -0.5864509 ]])

# %%
x_train,x_test,y_train,y_test =train_test_split(x,y,random_state=13,train_size=0.80)

# %%
model=KNeighborsClassifier(n_neighbors=3)
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
from sklearn.metrics import classification_report,accuracy_score

# %%
pred=model.predict(x_test)
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.47      0.89      0.62         9
#            2       0.86      0.67      0.75        18
#            3       0.00      0.00      0.00         3
#            5       1.00      0.67      0.80         3
#            6       1.00      1.00      1.00         2
#            7       1.00      0.88      0.93         8
#
#     accuracy                           0.72        43
#    macro avg       0.72      0.68      0.68        43
# weighted avg       0.76      0.72      0.72        43

# %%
a=[]
for k in range(1,30,2):
    model=KNeighborsClassifier(n_neighbors=k)
    model.fit(x_train,y_train)
    pre=model.predict(x_test)
    a.append(accuracy_score(y_test,pre))

# %%
plt.figure(figsize=(10,6))
plt.bar(range(1,30,2),a)
plt.xticks(range(1,30,2))
# Out:
# ([<matplotlib.axis.XTick at 0x2400cea8250>,
#   <matplotlib.axis.XTick at 0x2400d3af450>,
#   <matplotlib.axis.XTick at 0x2400d3aef10>,
#   <matplotlib.axis.XTick at 0x2400f409c10>,
#   <matplotlib.axis.XTick at 0x2400f4146d0>,
#   <matplotlib.axis.XTick at 0x2400f416610>,
#   <matplotlib.axis.XTick at 0x2400f418450>,
#   <matplotlib.axis.XTick at 0x2400f41aa10>,
#   <matplotlib.axis.XTick at 0x2400f41ba10>,
#   <matplotlib.axis.XTick at 0x2400f429650>,
#   <matplotlib.axis.XTick at 0x2400f42b750>,
#   <matplotlib.axis.XTick at 0x2400f42d910>,
#   <matplotlib.axis.XTick at 0x2400f42fa90>,
#   <matplotlib.axis.XTick at 0x2400f42d2d0>,
#   <matplotlib.axis.XTick at 0x2400f4363d0>],
#  [Text(1, 0, '1'),
#   Text(3, 0, '3'),
#   Text(5, 0, '5'),
#   Text(7, 0, '7'),
#   Text(9, 0, '9'),
#   Text(11, 0, '11'),
#   Text(13, 0, '13'),
#   Text(15, 0, '15'),
#   Text(17, 0, '17'),
#   Text(19, 0, '19'),
#   Text(21, 0, '21'),
#   Text(23, 0, '23'),
#   Text(25, 0, '25'),
#   Text(27, 0, '27'),
#   Text(29, 0, '29')])

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import GridSearchCV

# %%
num_fold = 10
Kfold = KFold(n_splits=10)

# %%
model = KNeighborsClassifier(n_neighbors=2)
model.fit(x_train,y_train)
results = cross_val_score(model,x,y,cv=Kfold)
results.mean()*100
# Out:
# 58.44155844155845
